# %% [markdown]
# # Cross-Entropy Method
#
# ---
#
# In this notebook, we will train the Cross-Entropy Method with OpenAI Gym's MountainCarContinuous environment.

# %% [markdown]
# ### 1. Import the Necessary Packages

# %%
import gym
import math
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
# env = gym.make('CartPole-v1')
# # env_s = env.action_space
# print(env_s.n)

# %% [markdown]
# ### 2. Instantiate the Environment and Agent

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

env = gym.make('MountainCarContinuous-v0')
# env = gym.make('CartPole-v1')
env.seed(101)
np.random.seed(101)

print('observation space:', env.observation_space)
print('action space:', env.action_space)
print('  - low:', env.action_space.low)
print('  - high:', env.action_space.high)

class Agent(nn.Module):
    def __init__(self, env, h_size=16):
        super(Agent, self).__init__()
        self.env = env
        # state, hidden layer, action sizes
        self.s_size = env.observation_space.shape[0]
        self.h_size = h_size
        self.a_size = env.action_space.shape[0]
        # define layers
        self.fc1 = nn.Linear(self.s_size, self.h_size)
        self.fc2 = nn.Linear(self.h_size, self.a_size)
        
    def set_weights(self, weights):
        s_size = self.s_size
        h_size = self.h_size
        a_size = self.a_size
        # separate the weights for each layer
        fc1_end = (s_size*h_size)+h_size
        fc1_W = torch.from_numpy(weights[:s_size*h_size].reshape(s_size, h_size))
        fc1_b = torch.from_numpy(weights[s_size*h_size:fc1_end])
        fc2_W = torch.from_numpy(weights[fc1_end:fc1_end+(h_size*a_size)].reshape(h_size, a_size))
        fc2_b = torch.from_numpy(weights[fc1_end+(h_size*a_size):])
        # set the weights for each layer
        self.fc1.weight.data.copy_(fc1_W.view_as(self.fc1.weight.data))
        self.fc1.bias.data.copy_(fc1_b.view_as(self.fc1.bias.data))
        self.fc2.weight.data.copy_(fc2_W.view_as(self.fc2.weight.data))
        self.fc2.bias.data.copy_(fc2_b.view_as(self.fc2.bias.data))
    
    def get_weights_dim(self):
        return (self.s_size+1)*self.h_size + (self.h_size+1)*self.a_size
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        action = x.cpu().data
        return action
        
    def evaluate(self, weights, gamma=1.0, max_t=5000):
        self.set_weights(weights)
        episode_return = 0.0
        state = self.env.reset()
        for t in range(max_t):
            state = torch.from_numpy(state).float().to(device)
            action = self.forward(state)
            state, reward, done, _ = self.env.step(action)
            episode_return += reward * math.pow(gamma, t)
            if done:
                break
        return episode_return
    
agent = Agent(env).to(device)
# Out:
# observation space: Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)
# action space: Box(-1.0, 1.0, (1,), float32)
#   - low: [-1.]
#   - high: [1.]

# %% [markdown]
# ### 3. Train the Agent with the Cross-Entropy Method
#
# Run the code cell below to train the agent from scratch.  Alternatively, you can skip to the next code cell to load the pre-trained weights from file.

# %%
def cem(n_iterations=500, max_t=1000, gamma=1.0, print_every=10, pop_size=50, elite_frac=0.2, sigma=0.5):
    """PyTorch implementation of the cross-entropy method.
        
    Params
    ======
        n_iterations (int): maximum number of training iterations
        max_t (int): maximum number of timesteps per episode
        gamma (float): discount rate
        print_every (int): how often to print average score (over last 100 episodes)
        pop_size (int): size of population at each iteration
        elite_frac (float): percentage of top performers to use in update
        sigma (float): standard deviation of additive noise
    """
    n_elite=int(pop_size*elite_frac)

    scores_deque = deque(maxlen=100)
    scores = []
    best_weight = sigma*np.random.randn(agent.get_weights_dim())

    for i_iteration in range(1, n_iterations+1):
        weights_pop = [best_weight + (sigma*np.random.randn(agent.get_weights_dim())) for i in range(pop_size)]
        rewards = np.array([agent.evaluate(weights, gamma, max_t) for weights in weights_pop])

        elite_idxs = rewards.argsort()[-n_elite:]
        elite_weights = [weights_pop[i] for i in elite_idxs]
        best_weight = np.array(elite_weights).mean(axis=0)

        reward = agent.evaluate(best_weight, gamma=1.0)
        scores_deque.append(reward)
        scores.append(reward)
        
        torch.save(agent.state_dict(), 'checkpoint.pth')
        
        if i_iteration % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))

        if np.mean(scores_deque)>=90.0:
            print('\nEnvironment solved in {:d} iterations!\tAverage Score: {:.2f}'.format(i_iteration-100, np.mean(scores_deque)))
            break
    return scores

scores = cem()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
fig.savefig('result.png')

#shut down computer after training
# import os
# os.system("shutdown /s /t 1")
# Out:
# Episode 10	Average Score: -1.44
# Episode 20	Average Score: -3.98
# Episode 30	Average Score: -4.18
# Episode 40	Average Score: 2.57
# Episode 50	Average Score: 18.74
# Episode 60	Average Score: 29.35
# Episode 70	Average Score: 38.69
# Episode 80	Average Score: 45.65
# Episode 90	Average Score: 47.98
# Episode 100	Average Score: 52.56
# Episode 110	Average Score: 62.09
# Episode 120	Average Score: 72.28
# Episode 130	Average Score: 82.21
# Episode 140	Average Score: 89.48
#
# Environment solved in 47 iterations!	Average Score: 90.83

# %% [markdown]
# ### 4. Watch a Smart Agent!
#
# In the next code cell, you will load the trained weights from file to watch a smart agent!

# %%
# load the weights from file
agent.load_state_dict(torch.load('checkpoint.pth'))

state = env.reset()
n = 0
i = 0
while True:
    i += 1
    state = torch.from_numpy(state).float().to(device)
    with torch.no_grad():
        action = agent(state)
    env.render()
    n += 1
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if i >= 100000:
        break
    if done:
        print('Finished the task in: {} steps'.format(n))
        n = 0
        state = env.reset()

env.close()
# Out:
# Finished the task in: 303 steps
# Finished the task in: 231 steps
# Finished the task in: 300 steps
# Finished the task in: 229 steps
# Finished the task in: 389 steps
# Finished the task in: 234 steps
# Finished the task in: 323 steps
# Finished the task in: 229 steps
# Finished the task in: 241 steps
# Finished the task in: 229 steps
# Finished the task in: 229 steps
# Finished the task in: 229 steps
# Finished the task in: 251 steps
# Finished the task in: 250 steps
# Finished the task in: 229 steps
# Finished the task in: 230 steps
# Finished the task in: 229 steps
# Finished the task in: 371 steps
# Finished the task in: 231 steps
# Finished the task in: 235 steps
# Finished the task in: 516 steps
# Finished the task in: 175 steps
# Finished the task in: 403 steps
# Finished the task in: 302 steps
# Finished the task in: 385 steps
# Finished the task in: 230 steps
# Finished the task in: 303 steps
# Finished the task in: 445 steps
# Finished the task in: 445 steps
# Finished the task in: 300 steps
# Finished the task in: 306 steps
# Finished the task in: 300 steps
# Finished the task in: 230 steps
# Finished the task in: 301 steps
# Finished the task in: 373 steps
# Finished the task in: 303 steps
# Finished the task in: 231 steps
# Finished the task in: 166 steps
# Finished the task in: 302 steps
# Finished the task in: 173 steps
# Finished the task in: 249 steps
# Finished the task in: 229 steps
# Finished the task in: 300 steps
# Finished the task in: 163 steps
# Finished the task in: 159 steps
# Finished the task in: 158 steps
# Finished the task in: 300 steps
# Finished the task in: 230 steps
# Finished the task in: 441 steps
# Finished the task in: 264 steps
# Finished the task in: 304 steps
# Finished the task in: 441 steps
# Finished the task in: 300 steps
# Finished the task in: 158 steps
# Finished the task in: 300 steps
# Finished the task in: 175 steps
# Finished the task in: 241 steps
# Finished the task in: 245 steps
# Finished the task in: 304 steps
# Finished the task in: 371 steps
# Finished the task in: 300 steps
# Finished the task in: 160 steps
# Finished the task in: 229 steps
# Finished the task in: 386 steps
# Finished the task in: 301 steps
# Finished the task in: 447 steps
# Finished the task in: 381 steps
# Finished the task in: 445 steps
# Finished the task in: 300 steps
# Finished the task in: 229 steps
# Finished the task in: 237 steps
# Finished the task in: 236 steps
# Finished the task in: 230 steps
# Finished the task in: 300 steps
# Finished the task in: 229 steps
# Finished the task in: 302 steps
# Finished the task in: 231 steps
# Finished the task in: 232 steps
# Finished the task in: 166 steps
# Finished the task in: 323 steps
# Finished the task in: 234 steps
# Finished the task in: 371 steps
# Finished the task in: 240 steps
# Finished the task in: 372 steps
# Finished the task in: 158 steps
# Finished the task in: 229 steps
# Finished the task in: 301 steps
# Finished the task in: 443 steps
# Finished the task in: 229 steps
# Finished the task in: 177 steps
# Finished the task in: 229 steps
# Finished the task in: 229 steps
# Finished the task in: 229 steps
# Finished the task in: 231 steps
# Finished the task in: 330 steps
# Finished the task in: 307 steps
# Finished the task in: 464 steps
# Finished the task in: 449 steps
# Finished the task in: 302 steps
# Finished the task in: 245 steps
# Finished the task in: 304 steps
# Finished the task in: 370 steps
# Finished the task in: 229 steps
# Finished the task in: 371 steps
# Finished the task in: 231 steps
# Finished the task in: 371 steps
# Finished the task in: 159 steps
# Finished the task in: 158 steps
# Finished the task in: 300 steps
# Finished the task in: 302 steps
# Finished the task in: 441 steps
# Finished the task in: 232 steps
# Finished the task in: 159 steps
# Finished the task in: 231 steps
# Finished the task in: 237 steps
# Finished the task in: 229 steps
# Finished the task in: 159 steps
# Finished the task in: 161 steps
# Finished the task in: 385 steps
# Finished the task in: 300 steps
# Finished the task in: 257 steps
# Finished the task in: 234 steps
# Finished the task in: 370 steps
# Finished the task in: 231 steps
# Finished the task in: 527 steps
# Finished the task in: 305 steps
# Finished the task in: 300 steps
# Finished the task in: 236 steps
# Finished the task in: 231 steps
# Finished the task in: 229 steps
# Finished the task in: 371 steps
# Finished the task in: 230 steps
# Finished the task in: 159 steps
# Finished the task in: 230 steps
# Finished the task in: 232 steps
# Finished the task in: 318 steps
# Finished the task in: 229 steps
# Finished the task in: 159 steps
# Finished the task in: 233 steps
# Finished the task in: 229 steps
# Finished the task in: 235 steps
# Finished the task in: 371 steps
# Finished the task in: 375 steps
# Finished the task in: 441 steps
# Finished the task in: 301 steps
# Finished the task in: 229 steps
# Finished the task in: 301 steps
# Finished the task in: 300 steps
# Finished the task in: 169 steps
# Finished the task in: 305 steps
